# %%
import matplotlib.pyplot as plt

days = [1,2,3,4,5,6,7]

NOP1 = [5,10,30,20,35,60,80]
NOP2 = [10,60,30,75,40,90,120]
NOP3 = [8,30,50,60,70,90,100]

plt.stackplot(days,NOP1,NOP2,NOP3,labels = ["week1","week2","week3"])
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_excel("C:/Users/AYUSH RAJ/Desktop/python data analytics/expense3.xlsx")
df = pd.DataFrame(data)
#print(df)
grouped = df.groupby(["Category"])["Calories","Protein","Fat"].mean()
#print(grouped)
#plt.stackplot(grouped["Category"],grouped["Calories"],grouped["protein"],grouped["Fat"])
plt.stackplot(df["Category"].unique(),grouped["Calories"],grouped["Protein"],grouped["Fat"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 7
#       5 df = pd.DataFrame(data)
#       6 #print(df)
# ----> 7 grouped = df.groupby(["Category"])["Calories","Protein","Fat"].mean()
#       8 #print(grouped)
#       9 #plt.stackplot(grouped["Category"],grouped["Calories"],grouped["protein"],grouped["Fat"])
#      10 plt.stackplot(df["Category"].unique(),grouped["Calories"],grouped["Protein"],grouped["Fat"])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:1947, in DataFrameGroupBy.__getitem__(self, key)
#    1943 # per GH 23566
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# -> 1947     raise ValueError(
# ...
